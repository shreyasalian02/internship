# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasalian02/internship/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("weather.csv/weather.csv")
df.head()
# Out:
#    day  pressure  maximum_temperature  temperature  minimum_temperature  \
# 0    1      1012                   32           30                   27
# 1    2      1010                   31           29                   26
# 2    3      1015                   33           31                   28
# 3    4      1008                   30           28                   25
# 4    5      1011                   34           32                   29
#
#    dew_point  humidity  cloud  rainfall  sunshine  wind_direction  wind_speed
# 0         24        80     60         5         6             180          12
# 1         23        78     55         2         7             170          10
# 2         25        82     65         0         8             160          14
# 3         22        75     50         1         7             150          11
# 4         26        85     70         3         6             140          13

# %%
df.head()
# Out:
#    day  pressure  maximum_temperature  temperature  minimum_temperature  \
# 0    1      1012                   32           30                   27
# 1    2      1010                   31           29                   26
# 2    3      1015                   33           31                   28
# 3    4      1008                   30           28                   25
# 4    5      1011                   34           32                   29
#
#    dew_point  humidity  cloud  rainfall  sunshine  wind_direction  wind_speed
# 0         24        80     60         5         6             180          12
# 1         23        78     55         2         7             170          10
# 2         25        82     65         0         8             160          14
# 3         22        75     50         1         7             150          11
# 4         26        85     70         3         6             140          13

# %%
df.shape
# Out:
# (5, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   day                  5 non-null      int64
#  1   pressure             5 non-null      int64
#  2   maximum_temperature  5 non-null      int64
#  3   temperature          5 non-null      int64
#  4   minimum_temperature  5 non-null      int64
#  5   dew_point            5 non-null      int64
#  6   humidity             5 non-null      int64
#  7   cloud                5 non-null      int64
#  8   rainfall             5 non-null      int64
#  9   sunshine             5 non-null      int64
#  10  wind_direction       5 non-null      int64
#  11  wind_speed           5 non-null      int64
# dtypes: int64(12)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#             day     pressure  maximum_temperature  temperature  \
# count  5.000000     5.000000             5.000000     5.000000
# mean   3.000000  1011.200000            32.000000    30.000000
# std    1.581139     2.588436             1.581139     1.581139
# min    1.000000  1008.000000            30.000000    28.000000
# 25%    2.000000  1010.000000            31.000000    29.000000
# 50%    3.000000  1011.000000            32.000000    30.000000
# 75%    4.000000  1012.000000            33.000000    31.000000
# max    5.000000  1015.000000            34.000000    32.000000
#
#        minimum_temperature  dew_point   humidity      cloud  rainfall  \
# count             5.000000   5.000000   5.000000   5.000000  5.000000
# mean             27.000000  24.000000  80.000000  60.000000  2.200000
# std               1.581139   1.581139   3.807887   7.905694  1.923538
# min              25.000000  22.000000  75.000000  50.000000  0.000000
# ...

# %%
df.isnull().sum()
# Out:
# day                    0
# pressure               0
# maximum_temperature    0
# temperature            0
# minimum_temperature    0
# dew_point              0
# humidity               0
# cloud                  0
# rainfall               0
# sunshine               0
# wind_direction         0
# wind_speed             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'pressure', 'maximum_temperature', 'temperature',
#        'minimum_temperature', 'dew_point', 'humidity', 'cloud', 'rainfall',
#        'sunshine', 'wind_direction', 'wind_speed'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.show()

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
plt.figure(figsize=(6,6))
df['rainfall'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)

plt.title("Rainfall Distribution")
plt.ylabel("")
plt.show()
